# %% [markdown]
# # Notebook 05: Forest Ecology & Ecosystem Monitoring
#
# This notebook documents the execution and provenance tracking of **Longitudinal Forest Ecosystem Monitoring & Canopy Dynamics** using `provBookR`.
#
# ### Ecological Objectives & Workflow:
# 1. **Inventory Survey**: Ingest plot inventory data across 8 forest monitoring plots (2020–2026).
# 2. **Allometric Biomass Estimation**: Compute Aboveground Biomass (AGB in $\text{Mg/ha}$) using allometric equations based on DBH ($cm$), stem density, and canopy cover percentage.
# 3. **Biodiversity Trajectory**: Calculate the Shannon Diversity Index ($H'$) across plots.
# 4. **Longitudinal Trends & Diagnostics**: Export summary metrics and multi-panel ecological plot diagnostics (`forest_canopy_biomass_trends.png`).

# %% [markdown]
# ## 1. Simulate Forest Inventory & Plot Survey Data

# %%
set.seed(204)
years <- 2020:2026
plots <- paste0("PLOT-", sprintf("%02d", 1:8))

plot_survey <- expand.grid(year = years, plot_id = plots)
n_obs <- nrow(plot_survey)

plot_survey$dbh_cm <- round(runif(n_obs, min = 12.0, max = 65.0), 1)
plot_survey$canopy_pct <- round(pmin(98, pmax(35, rnorm(n_obs, mean = 75, sd = 12))), 1)
plot_survey$stem_count <- sample(45:180, n_obs, replace = TRUE)
plot_survey$species_richness <- sample(4:16, n_obs, replace = TRUE)

# %% [markdown]
# ## 2. Ecological Allometric Biomass & Diversity Calculations

# %%
# Allometric equation for aboveground tree biomass (AGB in Mg/ha)
plot_survey$agb_biomass_mg_ha <- round(0.0673 * (plot_survey$dbh_cm ^ 2.47) * (plot_survey$stem_count / 1000), 2)

# Shannon Diversity Index approximation: H = log(richness) * (canopy_pct / 100)
plot_survey$shannon_index <- round(log(plot_survey$species_richness) * (plot_survey$canopy_pct / 100), 3)

# %% [markdown]
# ## 3. Longitudinal Ecosystem Aggregation

# %%
annual_ecology_summary <- aggregate(
  cbind(dbh_cm, canopy_pct, agb_biomass_mg_ha, shannon_index) ~ year,
  data = plot_survey,
  FUN = function(x) round(mean(x), 2)
)

# %% [markdown]
# ## 4. Generate Forest Biomass & Canopy Trend Diagnostics

# %%
png("forest_canopy_biomass_trends.png", width = 850, height = 550)
par(mfrow = c(1, 2), mar = c(4.5, 4.5, 3, 1))

# Panel A: Biomass Trajectory over Years
plot(
  annual_ecology_summary$year, annual_ecology_summary$agb_biomass_mg_ha,
  type = "b", col = "#1b5e20", lwd = 2.5, pch = 18, cex = 1.5,
  main = "Aboveground Biomass (Mg/ha)",
  xlab = "Survey Year", ylab = "Mean Biomass (Mg/ha)"
)
grid()

# Panel B: Canopy Cover vs Shannon Diversity Index
plot(
  plot_survey$canopy_pct, plot_survey$shannon_index,
  col = adjustcolor("#004d40", alpha.f = 0.6), pch = 16, cex = 1.2,
  main = "Canopy Cover vs Shannon Index",
  xlab = "Canopy Cover (%)", ylab = "Shannon Diversity (H')"
)
abline(lm(shannon_index ~ canopy_pct, data = plot_survey), col = "#d84315", lwd = 2, lty = 2)
grid()

dev.off()

saveRDS(annual_ecology_summary, "forest_ecology_assessment.rds")
cat("Forest Ecology Analysis completed successfully!")
# Out:
# agg_record_35b32c568c1b
#                       2
# Forest Ecology Analysis completed successfully!

# %%
provBookR::publish_codex("notebooks/05_forest_ecology_monitoring.R", output_dir = "books/forest_ecology_monitoring")
# Out:
# Executing script and collecting provenance...
#
# Tracing function "write.table" in package "utils"
#
# Tracing function "write" in package "namespace:base"
#
# Tracing function "writeLines" in package "namespace:base"
#
# Tracing function "writeChar" in package "namespace:base"
#
# Tracing function "writeBin" in package "namespace:base"
#
# Tracing function "saveRDS" in package "namespace:base"
#
# Tracing function "save" in package "namespace:base"
#
# Tracing function "dput" in package "namespace:base"
#
# Tracing function "dump" in package "namespace:base"
#
# Tracing function "data" in package "utils"
#
# Tracing function "read.table" in package "utils"
#
# Tracing function "read.dcf" in package "namespace:base"
#
# Tracing function "readRDS" in package "namespace:base"
#
# Tracing function "readLines" in package "namespace:base"
#
# Tracing function "readBin" in package "namespace:base"
#
# Tracing function "readChar" in package "namespace:base"
#
# Tracing function "scan" in package "namespace:base"
#
# Tracing function "load" in package "namespace:base"
#
# Tracing function "readRenviron" in package "namespace:base"
#
# Tracing function "source" in package "namespace:base"
#
# Tracing function "close.connection" in package "namespace:base"
#
# Tracing function "pdf" in package "grDevices"
#
# Tracing function "cairo_pdf" in package "grDevices"
#
# Tracing function "postscript" in package "grDevices"
#
# Tracing function "cairo_ps" in package "grDevices"
#
# Tracing function "bmp" in package "grDevices"
#
# Tracing function "jpeg" in package "grDevices"
#
# Tracing function "png" in package "grDevices"
#
# Tracing function "svg" in package "grDevices"
#
# Tracing function "tiff" in package "grDevices"
#
# Tracing function "x11" in package "grDevices"
#
# Tracing function "X11" in package "grDevices"
#
# Tracing function "quartz" in package "grDevices"
#
# Tracing function "abline" in package "graphics"
#
# Tracing function "arrows" in package "graphics"
#
# Tracing function "assocplot" in package "graphics"
#
# Tracing function "axis" in package "graphics"
#
# Tracing function "Axis" in package "graphics"
#
# Tracing function "axis.Date" in package "graphics"
#
# Tracing function "axis.POSIXct" in package "graphics"
#
# Tracing function "axTicks" in package "graphics"
#
# Tracing function "barplot" in package "graphics"
#
# Tracing function "barplot.default" in package "graphics"
#
# Tracing function "box" in package "graphics"
#
# Tracing function "boxplot" in package "graphics"
#
# Tracing function "boxplot.default" in package "graphics"
#
# Tracing function "boxplot.matrix" in package "graphics"
#
# Tracing function "bxp" in package "graphics"
#
# Tracing function "cdplot" in package "graphics"
#
# Tracing function "clip" in package "graphics"
#
# Tracing function "close.screen" in package "graphics"
#
# Tracing function "co.intervals" in package "graphics"
#
# Tracing function "contour" in package "graphics"
#
# Tracing function "contour.default" in package "graphics"
#
# Tracing function "coplot" in package "graphics"
#
# Tracing function "curve" in package "graphics"
#
# Tracing function "dotchart" in package "graphics"
#
# Tracing function "erase.screen" in package "graphics"
#
# Tracing function "filled.contour" in package "graphics"
#
# Tracing function "fourfoldplot" in package "graphics"
#
# Tracing function "frame" in package "graphics"
#
# Tracing function "grconvertX" in package "graphics"
#
# Tracing function "grconvertY" in package "graphics"
#
# Tracing function "grid" in package "graphics"
#
# Tracing function "hist" in package "graphics"
#
# Tracing function "hist.default" in package "graphics"
#
# Tracing function "identify" in package "graphics"
#
# Tracing function "image" in package "graphics"
#
# Tracing function "image.default" in package "graphics"
#
# Tracing function "layout" in package "graphics"
#
# Tracing function "layout.show" in package "graphics"
#
# Tracing function "lcm" in package "graphics"
#
# Tracing function "legend" in package "graphics"
#
# Tracing function "lines" in package "graphics"
#
# Tracing function "lines.default" in package "graphics"
#
# Tracing function "locator" in package "graphics"
#
# Tracing function "matlines" in package "graphics"
#
# Tracing function "matplot" in package "graphics"
#
# Tracing function "matpoints" in package "graphics"
#
# Tracing function "mosaicplot" in package "graphics"
#
# Tracing function "mtext" in package "graphics"
#
# Tracing function "pairs" in package "graphics"
#
# Tracing function "pairs.default" in package "graphics"
#
# Tracing function "panel.smooth" in package "graphics"
#
# Tracing function "par" in package "graphics"
#
# Tracing function "persp" in package "graphics"
#
# Tracing function "pie" in package "graphics"
#
# Tracing function "plot" in package "namespace:base"
#
# Tracing function "plot.default" in package "graphics"
#
# Tracing function "plot.design" in package "graphics"
#
# Tracing function "plot.function" in package "graphics"
#
# Tracing function "plot.new" in package "graphics"
#
# Tracing function "plot.window" in package "graphics"
#
# Tracing function "plot.xy" in package "graphics"
#
# Tracing function "points" in package "graphics"
#
# Tracing function "points.default" in package "graphics"
#
# Tracing function "polygon" in package "graphics"
#
# Tracing function "polypath" in package "graphics"
#
# Tracing function "rasterImage" in package "graphics"
#
# Tracing function "rect" in package "graphics"
#
# Tracing function "rug" in package "graphics"
#
# Tracing function "screen" in package "graphics"
#
# Tracing function "segments" in package "graphics"
#
# Tracing function "smoothScatter" in package "graphics"
#
# Tracing function "spineplot" in package "graphics"
#
# Tracing function "split.screen" in package "graphics"
#
# Tracing function "stars" in package "graphics"
#
# Tracing function "stem" in package "graphics"
#
# Tracing function "strheight" in package "graphics"
#
# Tracing function "stripchart" in package "graphics"
#
# Tracing function "strwidth" in package "graphics"
#
# Tracing function "sunflowerplot" in package "graphics"
#
# Tracing function "symbols" in package "graphics"
#
# Tracing function "text" in package "graphics"
#
# Tracing function "text.default" in package "graphics"
#
# Tracing function "title" in package "graphics"
#
# Tracing function "xinch" in package "graphics"
#
# Tracing function "xspline" in package "graphics"
#
# Tracing function "xyinch" in package "graphics"
#
# Tracing function "yinch" in package "graphics"
#
# Tracing function "dev.off" in package "grDevices"
# Forest Ecology Analysis completed successfully! Monitored 8 survey plots over 7 years.
# Untracing function "write.table" in package "utils"
#
# Untracing function "write" in package "namespace:base"
#
# Untracing function "writeLines" in package "namespace:base"
#
# Untracing function "writeChar" in package "namespace:base"
#
# Untracing function "writeBin" in package "namespace:base"
#
# Untracing function "saveRDS" in package "namespace:base"
#
# Untracing function "save" in package "namespace:base"
#
# Untracing function "dput" in package "namespace:base"
#
# Untracing function "dump" in package "namespace:base"
#
# Untracing function "data" in package "utils"
#
# Untracing function "read.table" in package "utils"
#
# Untracing function "read.dcf" in package "namespace:base"
#
# Untracing function "readRDS" in package "namespace:base"
#
# Untracing function "readLines" in package "namespace:base"
#
# Untracing function "readBin" in package "namespace:base"
#
# Untracing function "readChar" in package "namespace:base"
#
# Untracing function "scan" in package "namespace:base"
#
# Untracing function "load" in package "namespace:base"
#
# Untracing function "readRenviron" in package "namespace:base"
#
# Untracing function "source" in package "namespace:base"
#
# Untracing function "close.connection" in package "namespace:base"
#
# Untracing function "pdf" in package "grDevices"
#
# Untracing function "cairo_pdf" in package "grDevices"
#
# Untracing function "postscript" in package "grDevices"
#
# Untracing function "cairo_ps" in package "grDevices"
#
# Untracing function "bmp" in package "grDevices"
#
# Untracing function "jpeg" in package "grDevices"
#
# Untracing function "png" in package "grDevices"
#
# Untracing function "svg" in package "grDevices"
#
# Untracing function "tiff" in package "grDevices"
#
# Untracing function "x11" in package "grDevices"
#
# Untracing function "X11" in package "grDevices"
#
# Untracing function "quartz" in package "grDevices"
#
# Untracing function "abline" in package "graphics"
#
# Untracing function "arrows" in package "graphics"
#
# Untracing function "assocplot" in package "graphics"
#
# Untracing function "axis" in package "graphics"
#
# Untracing function "Axis" in package "graphics"
#
# Untracing function "axis.Date" in package "graphics"
#
# Untracing function "axis.POSIXct" in package "graphics"
#
# Untracing function "axTicks" in package "graphics"
#
# Untracing function "barplot" in package "graphics"
#
# Untracing function "barplot.default" in package "graphics"
#
# Untracing function "box" in package "graphics"
#
# Untracing function "boxplot" in package "graphics"
#
# Untracing function "boxplot.default" in package "graphics"
#
# Untracing function "boxplot.matrix" in package "graphics"
#
# Untracing function "bxp" in package "graphics"
#
# Untracing function "cdplot" in package "graphics"
#
# Untracing function "clip" in package "graphics"
#
# Untracing function "close.screen" in package "graphics"
#
# Untracing function "co.intervals" in package "graphics"
#
# Untracing function "contour" in package "graphics"
#
# Untracing function "contour.default" in package "graphics"
#
# Untracing function "coplot" in package "graphics"
#
# Untracing function "curve" in package "graphics"
#
# Untracing function "dotchart" in package "graphics"
#
# Untracing function "erase.screen" in package "graphics"
#
# Untracing function "filled.contour" in package "graphics"
#
# Untracing function "fourfoldplot" in package "graphics"
#
# Untracing function "frame" in package "graphics"
#
# Untracing function "grconvertX" in package "graphics"
#
# Untracing function "grconvertY" in package "graphics"
#
# Untracing function "grid" in package "graphics"
#
# Untracing function "hist" in package "graphics"
#
# Untracing function "hist.default" in package "graphics"
#
# Untracing function "identify" in package "graphics"
#
# Untracing function "image" in package "graphics"
#
# Untracing function "image.default" in package "graphics"
#
# Untracing function "layout" in package "graphics"
#
# Untracing function "layout.show" in package "graphics"
#
# Untracing function "lcm" in package "graphics"
#
# Untracing function "legend" in package "graphics"
#
# Untracing function "lines" in package "graphics"
#
# Untracing function "lines.default" in package "graphics"
#
# Untracing function "locator" in package "graphics"
#
# Untracing function "matlines" in package "graphics"
#
# Untracing function "matplot" in package "graphics"
#
# Untracing function "matpoints" in package "graphics"
#
# Untracing function "mosaicplot" in package "graphics"
#
# Untracing function "mtext" in package "graphics"
#
# Untracing function "pairs" in package "graphics"
#
# Untracing function "pairs.default" in package "graphics"
#
# Untracing function "panel.smooth" in package "graphics"
#
# Untracing function "par" in package "graphics"
#
# Untracing function "persp" in package "graphics"
#
# Untracing function "pie" in package "graphics"
#
# Untracing function "plot" in package "namespace:base"
#
# Untracing function "plot.default" in package "graphics"
#
# Untracing function "plot.design" in package "graphics"
#
# Untracing function "plot.function" in package "graphics"
#
# Untracing function "plot.new" in package "graphics"
#
# Untracing function "plot.window" in package "graphics"
#
# Untracing function "plot.xy" in package "graphics"
#
# Untracing function "points" in package "graphics"
#
# Untracing function "points.default" in package "graphics"
#
# Untracing function "polygon" in package "graphics"
#
# Untracing function "polypath" in package "graphics"
#
# Untracing function "rasterImage" in package "graphics"
#
# Untracing function "rect" in package "graphics"
#
# Untracing function "rug" in package "graphics"
#
# Untracing function "screen" in package "graphics"
#
# Untracing function "segments" in package "graphics"
#
# Untracing function "smoothScatter" in package "graphics"
#
# Untracing function "spineplot" in package "graphics"
#
# Untracing function "split.screen" in package "graphics"
#
# Untracing function "stars" in package "graphics"
#
# Untracing function "stem" in package "graphics"
#
# Untracing function "strheight" in package "graphics"
#
# Untracing function "stripchart" in package "graphics"
#
# Untracing function "strwidth" in package "graphics"
#
# Untracing function "sunflowerplot" in package "graphics"
#
# Untracing function "symbols" in package "graphics"
#
# Untracing function "text" in package "graphics"
#
# Untracing function "text.default" in package "graphics"
#
# Untracing function "title" in package "graphics"
#
# Untracing function "xinch" in package "graphics"
#
# Untracing function "xspline" in package "graphics"
#
# Untracing function "xyinch" in package "graphics"
#
# Untracing function "yinch" in package "graphics"
#
# Untracing function "dev.off" in package "grDevices"
#
# Scaffolding SvelteKit codex...
#
# Building static booklet (this requires Node.js)...
#
# Copying build to books/forest_ecology_monitoring...
#
# Codex successfully published at: books/forest_ecology_monitoring/index.html
# [1] TRUE

# %%
provBookR::preview_codex("books/forest_ecology_monitoring")
# Out:
# Serving books/forest_ecology_monitoring on http://localhost:8000 ... Press Ctrl+C to stop.
